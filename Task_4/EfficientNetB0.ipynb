# %%
import os
import numpy as np
import tensorflow as tf
import rasterio
import matplotlib.pyplot as plt
from glob import glob
from rasterio.plot import show
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, Model
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.metrics import MeanIoU
from tensorflow import keras

# %%
# Paths to images and labels
data_dir = r"C:\Users\Eman\Downloads\images-20250217T060743Z-001\images"
labels_dir = r"C:\Users\Eman\Downloads\labels-20250217T060744Z-001\labels"

# %%
# Load TIFF images (12-band) and apply min-max normalization
def load_image(image_path):
    with rasterio.open(image_path) as src:
        image = src.read().astype(np.float32)  # Shape: (12, 128, 128)
        image = np.transpose(image, (1, 2, 0))  # Convert to (128, 128, 12)

    # Min-max normalization per channel
    min_val = np.min(image, axis=(0, 1), keepdims=True)
    max_val = np.max(image, axis=(0, 1), keepdims=True)
    
    # Avoid division by zero
    normalized_image = (image - min_val) / (max_val - min_val + 1e-7)
    
    return normalized_image

# %%
# Normalize label images
def load_label(label_path):
    label = tf.keras.preprocessing.image.load_img(label_path, color_mode="grayscale")
    label = np.array(label, dtype=np.uint8)  # Convert to numpy array
    label = (label > 0).astype(np.int32)  # Ensure binary format
    return label

# %%
# Get sorted lists of image and label file paths
image_paths = sorted(glob(os.path.join(data_dir, "*.tif")))
label_paths = sorted(glob(os.path.join(labels_dir, "*.png")))

# Split dataset into training and testing
train_images, test_images, train_labels, test_labels = train_test_split(
    image_paths, label_paths, test_size=0.2, random_state=42
)

# %%
# Prepare dataset for training
def preprocess_data(image_paths, label_paths):
    images = np.array([load_image(p) for p in image_paths])
    labels = np.array([load_label(p) for p in label_paths])
    labels = np.expand_dims(labels, axis=-1)  # Add channel dimension
    return images, labels

train_images_np, train_labels_np = preprocess_data(train_images, train_labels)
test_images_np, test_labels_np = preprocess_data(test_images, test_labels)
train_labels_np = tf.image.resize(train_labels_np, (64, 64))
test_labels_np = tf.image.resize(test_labels_np, (64, 64))
# Out:
# C:\Users\Eman\anaconda3\Lib\site-packages\rasterio\__init__.py:368: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)

# %%
# Fine-Tune a Pretrained Model (EfficientNet as Encoder)
def build_finetuned_unet(input_shape=(128, 128, 12)):
    # Load a pre-trained EfficientNetB0 encoder
    base_model = EfficientNetB0(input_shape=(128, 128, 3), include_top=False, weights="imagenet")

    # Extend it to 12-band images using Conv2D
    input_layer = layers.Input(shape=input_shape)
    processed_input = layers.Conv2D(3, (1, 1), activation="relu", padding="same")(input_layer)  # Reduce bands to 3

    # Pass through pre-trained encoder
    encoder_output = base_model(processed_input)

    # Decoder with upsampling layers
    x = layers.Conv2DTranspose(256, (3, 3), strides=(2, 2), padding="same", activation="relu")(encoder_output)
    x = layers.Conv2DTranspose(128, (3, 3), strides=(2, 2), padding="same", activation="relu")(x)
    x = layers.Conv2DTranspose(64, (3, 3), strides=(2, 2), padding="same", activation="relu")(x)
    x = layers.Conv2DTranspose(32, (3, 3), strides=(2, 2), padding="same", activation="relu")(x)

    output_layer = layers.Conv2D(1, (1, 1), activation="sigmoid")(x)

    # Build model
    model = Model(inputs=input_layer, outputs=output_layer)

    # Freeze encoder for initial training
    for layer in base_model.layers[:100]:
        layer.trainable = False

    model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.0001),
                  loss="binary_crossentropy",
                  metrics=["accuracy"])

    return model

# %%
# Initialize and train the model
finetuned_model = build_finetuned_unet()
finetuned_model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 128, 128, 12)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 128, 128, 3)         │              39 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ efficientnetb0 (Functional)          │ (None, 4, 4, 1280)          │       4,049,571 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose (Conv2DTranspose)   │ (None, 8, 8, 256)           │       2,949,376 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose_1 (Conv2DTranspose) │ (None, 16, 16, 128)         │         295,040 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose_2 (Conv2DTranspose) │ (None, 32, 32, 64)          │          73,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose_3 (Conv2DTranspose) │ (None, 64, 64, 32)          │          18,464 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 64, 64, 1)           │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,386,315 (28.18 MB)
#  Trainable params: 7,177,092 (27.38 MB)
#  Non-trainable params: 209,223 (817.28 KB)

# %%
# Train the model with fine-tuning
finetuned_model.fit(train_images_np, train_labels_np, epochs=30, batch_size=8, validation_data=(test_images_np, test_labels_np))
# Out:
# Epoch 1/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 51s 512ms/step - accuracy: 0.7078 - loss: 0.6727 - val_accuracy: 0.7599 - val_loss: 0.6688
# Epoch 2/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 16s 368ms/step - accuracy: 0.7250 - loss: 0.6098 - val_accuracy: 0.7599 - val_loss: 0.6429
# Epoch 3/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 9s 306ms/step - accuracy: 0.7294 - loss: 0.5709 - val_accuracy: 0.7599 - val_loss: 0.6233
# Epoch 4/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 10s 329ms/step - accuracy: 0.6790 - loss: 0.5945 - val_accuracy: 0.7599 - val_loss: 0.6089
# Epoch 5/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 10s 328ms/step - accuracy: 0.7261 - loss: 0.5305 - val_accuracy: 0.7599 - val_loss: 0.6083
# Epoch 6/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 12s 384ms/step - accuracy: 0.7351 - loss: 0.5271 - val_accuracy: 0.7599 - val_loss: 0.5979
# Epoch 7/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 17s 275ms/step - accuracy: 0.7196 - loss: 0.5178 - val_accuracy: 0.7599 - val_loss: 0.5925
# Epoch 8/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 8s 269ms/step - accuracy: 0.7008 - loss: 0.5306 - val_accuracy: 0.7599 - val_loss: 0.5593
# Epoch 9/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 13s 349ms/step - accuracy: 0.7093 - loss: 0.5027 - val_accuracy: 0.7599 - val_loss: 0.5553
# Epoch 10/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 346ms/step - accuracy: 0.7016 - loss: 0.5299 - val_accuracy: 0.7599 - val_loss: 0.5153
# Epoch 11/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 355ms/step - accuracy: 0.6770 - loss: 0.5192 - val_accuracy: 0.7599 - val_loss: 0.5044
# Epoch 12/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 348ms/step - accuracy: 0.7278 - loss: 0.4581 - val_accuracy: 0.7599 - val_loss: 0.5099
# Epoch 13/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 345ms/step - accuracy: 0.6884 - loss: 0.4966 - val_accuracy: 0.7599 - val_loss: 0.5517
# Epoch 14/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 353ms/step - accuracy: 0.7050 - loss: 0.4666 - val_accuracy: 0.7599 - val_loss: 0.5977
# Epoch 15/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 350ms/step - accuracy: 0.7200 - loss: 0.4693 - val_accuracy: 0.7599 - val_loss: 0.4978
# Epoch 16/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 354ms/step - accuracy: 0.7153 - loss: 0.4565 - val_accuracy: 0.7599 - val_loss: 0.4342
# Epoch 17/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 356ms/step - accuracy: 0.7215 - loss: 0.4681 - val_accuracy: 0.7599 - val_loss: 0.5361
# Epoch 18/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 347ms/step - accuracy: 0.7146 - loss: 0.4739 - val_accuracy: 0.7671 - val_loss: 0.4036
# Epoch 19/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 351ms/step - accuracy: 0.7760 - loss: 0.4247 - val_accuracy: 0.7631 - val_loss: 0.3847
# Epoch 20/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 356ms/step - accuracy: 0.7451 - loss: 0.4684 - val_accuracy: 0.7599 - val_loss: 0.6147
# Epoch 21/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 345ms/step - accuracy: 0.7592 - loss: 0.4175 - val_accuracy: 0.7965 - val_loss: 0.3670
# Epoch 22/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 13s 415ms/step - accuracy: 0.7767 - loss: 0.4430 - val_accuracy: 0.7630 - val_loss: 0.5302
# Epoch 23/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 13s 400ms/step - accuracy: 0.7801 - loss: 0.4225 - val_accuracy: 0.7666 - val_loss: 0.4718
# Epoch 24/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 341ms/step - accuracy: 0.7518 - loss: 0.4490 - val_accuracy: 0.7650 - val_loss: 0.7339
# Epoch 25/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 10s 337ms/step - accuracy: 0.8009 - loss: 0.4133 - val_accuracy: 0.8293 - val_loss: 0.4225
# Epoch 26/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 340ms/step - accuracy: 0.7578 - loss: 0.4530 - val_accuracy: 0.8201 - val_loss: 0.3708
# Epoch 27/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 342ms/step - accuracy: 0.7581 - loss: 0.4533 - val_accuracy: 0.7635 - val_loss: 0.6605
# Epoch 28/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 348ms/step - accuracy: 0.7573 - loss: 0.4532 - val_accuracy: 0.8187 - val_loss: 0.4565
# Epoch 29/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 20s 344ms/step - accuracy: 0.8074 - loss: 0.4014 - val_accuracy: 0.8247 - val_loss: 0.3645
# Epoch 30/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 344ms/step - accuracy: 0.8159 - loss: 0.4127 - val_accuracy: 0.7838 - val_loss: 0.4277

# %%
# Custom IoU metric
def iou_metric(y_true, y_pred):
    y_pred = tf.cast(y_pred > 0.5, tf.int32)
    y_true = tf.cast(y_true, tf.int32)

    intersection = tf.reduce_sum(tf.cast(y_true * y_pred, tf.float32))
    union = tf.reduce_sum(tf.cast(y_true + y_pred, tf.float32)) - intersection
    iou = (intersection + 1e-7) / (union + 1e-7)
    return iou

# Custom F1-score metric
def f1_score_metric(y_true, y_pred):
    y_pred = tf.cast(y_pred > 0.5, tf.int32)
    y_true = tf.cast(y_true, tf.int32)

    tp = tf.reduce_sum(tf.cast(y_true * y_pred, tf.float32))
    fp = tf.reduce_sum(tf.cast((1 - y_true) * y_pred, tf.float32))
    fn = tf.reduce_sum(tf.cast(y_true * (1 - y_pred), tf.float32))

    precision = tp / (tp + fp + 1e-7)
    recall = tp / (tp + fn + 1e-7)

    f1 = 2 * (precision * recall) / (precision + recall + 1e-7)
    return f1

# %%
# Unfreeze some encoder layers and continue fine-tuning
for layer in finetuned_model.layers[:100]:
    layer.trainable = True

finetuned_model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-5),
                        loss="binary_crossentropy",
                        metrics=["accuracy", iou_metric, f1_score_metric])

finetuned_model.fit(train_images_np, train_labels_np, epochs=30, batch_size=8, validation_data=(test_images_np, test_labels_np))
# Out:
# Epoch 1/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 54s 625ms/step - accuracy: 0.8092 - f1_score_metric: 0.5418 - iou_metric: 0.3920 - loss: 0.3950 - val_accuracy: 0.7942 - val_f1_score_metric: 0.3125 - val_iou_metric: 0.1952 - val_loss: 0.3879
# Epoch 2/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 18s 528ms/step - accuracy: 0.7750 - f1_score_metric: 0.4986 - iou_metric: 0.3472 - loss: 0.4100 - val_accuracy: 0.8138 - val_f1_score_metric: 0.4468 - val_iou_metric: 0.2967 - val_loss: 0.3694
# Epoch 3/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 17s 540ms/step - accuracy: 0.7784 - f1_score_metric: 0.5062 - iou_metric: 0.3546 - loss: 0.4297 - val_accuracy: 0.8307 - val_f1_score_metric: 0.5466 - val_iou_metric: 0.3871 - val_loss: 0.3597
# Epoch 4/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 19s 499ms/step - accuracy: 0.7746 - f1_score_metric: 0.5100 - iou_metric: 0.3558 - loss: 0.4315 - val_accuracy: 0.8332 - val_f1_score_metric: 0.5763 - val_iou_metric: 0.4162 - val_loss: 0.3570
# Epoch 5/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 21s 523ms/step - accuracy: 0.7874 - f1_score_metric: 0.5229 - iou_metric: 0.3701 - loss: 0.4078 - val_accuracy: 0.8354 - val_f1_score_metric: 0.5955 - val_iou_metric: 0.4344 - val_loss: 0.3562
# Epoch 6/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 21s 535ms/step - accuracy: 0.8103 - f1_score_metric: 0.5424 - iou_metric: 0.3928 - loss: 0.3732 - val_accuracy: 0.8365 - val_f1_score_metric: 0.5972 - val_iou_metric: 0.4372 - val_loss: 0.3521
# Epoch 7/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 21s 542ms/step - accuracy: 0.7965 - f1_score_metric: 0.5615 - iou_metric: 0.4110 - loss: 0.4002 - val_accuracy: 0.8384 - val_f1_score_metric: 0.6023 - val_iou_metric: 0.4419 - val_loss: 0.3544
# Epoch 8/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 15s 484ms/step - accuracy: 0.7844 - f1_score_metric: 0.5359 - iou_metric: 0.3780 - loss: 0.4086 - val_accuracy: 0.8364 - val_f1_score_metric: 0.6135 - val_iou_metric: 0.4532 - val_loss: 0.3813
# Epoch 9/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 20s 463ms/step - accuracy: 0.7957 - f1_score_metric: 0.5942 - iou_metric: 0.4372 - loss: 0.3996 - val_accuracy: 0.8358 - val_f1_score_metric: 0.6183 - val_iou_metric: 0.4584 - val_loss: 0.3944
# Epoch 10/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 21s 487ms/step - accuracy: 0.8056 - f1_score_metric: 0.5535 - iou_metric: 0.4017 - loss: 0.3699 - val_accuracy: 0.8394 - val_f1_score_metric: 0.6111 - val_iou_metric: 0.4509 - val_loss: 0.3567
# Epoch 11/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 17s 381ms/step - accuracy: 0.8175 - f1_score_metric: 0.5215 - iou_metric: 0.3800 - loss: 0.3629 - val_accuracy: 0.8390 - val_f1_score_metric: 0.6023 - val_iou_metric: 0.4413 - val_loss: 0.3524
# Epoch 12/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 348ms/step - accuracy: 0.8128 - f1_score_metric: 0.5868 - iou_metric: 0.4242 - loss: 0.3797 - val_accuracy: 0.8371 - val_f1_score_metric: 0.6179 - val_iou_metric: 0.4584 - val_loss: 0.3856
# Epoch 13/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 13s 415ms/step - accuracy: 0.8057 - f1_score_metric: 0.6119 - iou_metric: 0.4480 - loss: 0.3861 - val_accuracy: 0.8399 - val_f1_score_metric: 0.6038 - val_iou_metric: 0.4428 - val_loss: 0.3536
# Epoch 14/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 16s 275ms/step - accuracy: 0.8164 - f1_score_metric: 0.5984 - iou_metric: 0.4500 - loss: 0.3828 - val_accuracy: 0.8395 - val_f1_score_metric: 0.5865 - val_iou_metric: 0.4244 - val_loss: 0.3659
# Epoch 15/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 13s 425ms/step - accuracy: 0.8239 - f1_score_metric: 0.6061 - iou_metric: 0.4481 - loss: 0.3631 - val_accuracy: 0.8393 - val_f1_score_metric: 0.5892 - val_iou_metric: 0.4266 - val_loss: 0.3599
# Epoch 16/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 13s 429ms/step - accuracy: 0.8110 - f1_score_metric: 0.6242 - iou_metric: 0.4666 - loss: 0.3871 - val_accuracy: 0.8398 - val_f1_score_metric: 0.5997 - val_iou_metric: 0.4374 - val_loss: 0.3607
# Epoch 17/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 356ms/step - accuracy: 0.8017 - f1_score_metric: 0.5828 - iou_metric: 0.4180 - loss: 0.3900 - val_accuracy: 0.8403 - val_f1_score_metric: 0.5976 - val_iou_metric: 0.4356 - val_loss: 0.3633
# Epoch 18/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 26s 518ms/step - accuracy: 0.8221 - f1_score_metric: 0.6105 - iou_metric: 0.4508 - loss: 0.3804 - val_accuracy: 0.8408 - val_f1_score_metric: 0.6243 - val_iou_metric: 0.4637 - val_loss: 0.3551
# Epoch 19/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 16s 517ms/step - accuracy: 0.8037 - f1_score_metric: 0.6368 - iou_metric: 0.4787 - loss: 0.3946 - val_accuracy: 0.8425 - val_f1_score_metric: 0.6238 - val_iou_metric: 0.4636 - val_loss: 0.3544
# Epoch 20/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 16s 367ms/step - accuracy: 0.8239 - f1_score_metric: 0.5905 - iou_metric: 0.4324 - loss: 0.3701 - val_accuracy: 0.8416 - val_f1_score_metric: 0.6040 - val_iou_metric: 0.4420 - val_loss: 0.3674
# Epoch 21/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 21s 396ms/step - accuracy: 0.8174 - f1_score_metric: 0.5489 - iou_metric: 0.3973 - loss: 0.3733 - val_accuracy: 0.8432 - val_f1_score_metric: 0.6194 - val_iou_metric: 0.4586 - val_loss: 0.3559
# Epoch 22/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 25s 538ms/step - accuracy: 0.8317 - f1_score_metric: 0.6272 - iou_metric: 0.4652 - loss: 0.3512 - val_accuracy: 0.8437 - val_f1_score_metric: 0.6254 - val_iou_metric: 0.4655 - val_loss: 0.3511
# Epoch 23/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 18s 456ms/step - accuracy: 0.8252 - f1_score_metric: 0.6333 - iou_metric: 0.4754 - loss: 0.3799 - val_accuracy: 0.8443 - val_f1_score_metric: 0.6130 - val_iou_metric: 0.4517 - val_loss: 0.3642
# Epoch 24/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 23s 522ms/step - accuracy: 0.8187 - f1_score_metric: 0.6400 - iou_metric: 0.4810 - loss: 0.3800 - val_accuracy: 0.8445 - val_f1_score_metric: 0.6069 - val_iou_metric: 0.4454 - val_loss: 0.3700
# Epoch 25/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 20s 501ms/step - accuracy: 0.8070 - f1_score_metric: 0.5612 - iou_metric: 0.4251 - loss: 0.4305 - val_accuracy: 0.8448 - val_f1_score_metric: 0.6279 - val_iou_metric: 0.4694 - val_loss: 0.3468
# Epoch 26/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 19s 459ms/step - accuracy: 0.8249 - f1_score_metric: 0.6541 - iou_metric: 0.4987 - loss: 0.3718 - val_accuracy: 0.8443 - val_f1_score_metric: 0.6130 - val_iou_metric: 0.4531 - val_loss: 0.3553
# Epoch 27/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 23s 515ms/step - accuracy: 0.8301 - f1_score_metric: 0.6613 - iou_metric: 0.5032 - loss: 0.3533 - val_accuracy: 0.8441 - val_f1_score_metric: 0.6076 - val_iou_metric: 0.4473 - val_loss: 0.3578
# Epoch 28/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 21s 535ms/step - accuracy: 0.8301 - f1_score_metric: 0.6652 - iou_metric: 0.5125 - loss: 0.3634 - val_accuracy: 0.8446 - val_f1_score_metric: 0.6073 - val_iou_metric: 0.4472 - val_loss: 0.3612
# Epoch 29/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 20s 527ms/step - accuracy: 0.8457 - f1_score_metric: 0.6535 - iou_metric: 0.4996 - loss: 0.3449 - val_accuracy: 0.8452 - val_f1_score_metric: 0.6270 - val_iou_metric: 0.4697 - val_loss: 0.3560
# Epoch 30/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 17s 557ms/step - accuracy: 0.7959 - f1_score_metric: 0.5855 - iou_metric: 0.4221 - loss: 0.3959 - val_accuracy: 0.8455 - val_f1_score_metric: 0.6228 - val_iou_metric: 0.4654 - val_loss: 0.3549

# %%
# Evaluate model performance
def evaluate_model(y_true, y_pred):
    y_true = tf.cast(y_true, tf.int32)
    y_pred = tf.cast(y_pred, tf.int32)
    
    iou = MeanIoU(num_classes=2)
    iou.update_state(y_true, y_pred)
    
    precision = tf.keras.metrics.Precision()
    precision.update_state(y_true, y_pred)
    
    recall = tf.keras.metrics.Recall()
    recall.update_state(y_true, y_pred)
    
    f1_score = 2 * (precision.result().numpy() * recall.result().numpy()) / \
               (precision.result().numpy() + recall.result().numpy() + 1e-7)
    
    print(f"IoU: {iou.result().numpy():.4f}, Precision: {precision.result().numpy():.4f}, "
          f"Recall: {recall.result().numpy():.4f}, F1-score: {f1_score:.4f}")

# Predict and evaluate
predictions = (finetuned_model.predict(test_images_np) > 0.5).astype(np.int32)
evaluate_model(test_labels_np, predictions)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 478ms/step
# IoU: 0.6605, Precision: 0.7068, Recall: 0.5942, F1-score: 0.6456

# %%
# Function to visualize RGB + ground truth + predictions
import os 
import numpy as np
import matplotlib.pyplot as plt
import random

def visualize_predictions_rgb(model, X_test, Y_test, num_samples=5, rgb_bands=(4, 3, 2)):
    plt.figure(figsize=(15, num_samples * 5))
    indices = random.sample(range(len(X_test)), num_samples)
    for i, idx in enumerate(indices):
        img = X_test[idx]
        true_mask = Y_test[idx]
        rgb_image = img[..., [rgb_bands[0]-1, rgb_bands[1]-1, rgb_bands[2]-1]]
        rgb_image = np.clip((rgb_image - rgb_image.min()) / (rgb_image.max() - rgb_image.min()), 0, 1)
        pred_mask = model.predict(img[np.newaxis, ...])[0, ..., 0]
        pred_mask = (pred_mask > 0.5).astype(np.uint8)
        plt.subplot(num_samples, 3, i * 3 + 1)
        plt.imshow(rgb_image)
        plt.title("RGB Image (Bands 4,3,2) - True Color")
        plt.axis("off")
        plt.subplot(num_samples, 3, i * 3 + 2)
        plt.imshow(true_mask, cmap="gray", vmin=0, vmax=1)
        plt.title("Ground Truth Mask")
        plt.axis("off")
        plt.subplot(num_samples, 3, i * 3 + 3)
        plt.imshow(pred_mask, cmap="gray", vmin=0, vmax=1)
        plt.title("Predicted Mask")
        plt.axis("off")
    plt.tight_layout()
    plt.show()

visualize_predictions_rgb(finetuned_model, test_images_np, test_labels_np, rgb_bands=(4, 3, 2))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
